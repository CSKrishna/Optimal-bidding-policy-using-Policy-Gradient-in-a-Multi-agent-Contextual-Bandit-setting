# %%
# %run learner.py -n 25000 -b 25 -l 3 -s 32 -lr 1e-3 --exp_name trial
# Out:
# Running experiment with seed 87

# %%
# %run plot.py data/trial_08-03-2018_20-52-49 --value AverageProfit_agt1 AverageProfit_agt2
